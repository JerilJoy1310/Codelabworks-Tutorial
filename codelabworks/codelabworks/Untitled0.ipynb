# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
from google.colab import files
from IPython.display import Image

# %%
image = cv2.imread("/content/aiswarya.jpg", 1)
eye_detection= cv2.CascadeClassifier('/content/haarcascade_eye.xml')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
eyes = eye_detection.detectMultiScale(gray_image, 1.03, 5)

for (x,y,w,h) in faces:
   eye = cv2.rectangle(image,(x,y),(x+w, y+h),(255,0,0),3)

    
Titles =["haar"] 
images =[eye] 
count = 1
  
for i in range(count): 
    plt.subplot(2, 2, i + 1) 
    plt.title(Titles[i]) 
    plt.imshow(images[i]) 
  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-1bb8e4dc12ae> in <module>()
#       6 eyes = eye_detection.detectMultiScale(gray_image, 1.03, 5)
#       7
# ----> 8 for (x,y,w,h) in faces:
#       9    eye = cv2.rectangle(image,(x,y),(x+w, y+h),(255,0,0),3)
#      10
#
# NameError: name 'faces' is not defined

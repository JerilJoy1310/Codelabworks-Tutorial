# %%
import csv
with open('countrycontribution.csv','w', newline='') as file: q=csv.writer(file)
q.writerow(["SN", "Name" , "Country" , "Contribution"])
q.writerow(["1" , "Linus Torvalds" , "Finland" , "Linux Kernel"]) 
q.writerow(["2" , "Tim Berners-Lee" , "England" , "World Wide Web"])  
q.writerow(["3" , "Guido van Rossum" , "Netherlands" , "Python"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-91351235d027> in <module>()
#       1 import csv
#       2 with open('countrycontribution.csv','w', newline='') as file: q=csv.writer(file)
# ----> 3 q.writerow(["SN", "Name" , "Country" , "Contribution"])
#       4 q.writerow(["1" , "Linus Torvalds" , "Finland" , "Linux Kernel"])
#       5 q.writerow(["2" , "Tim Berners-Lee" , "England" , "World Wide Web"])
#
# ValueError: I/O operation on closed file.

# %%
class Rectangle:
  def init (self,height,width,corner_x,corner_y):
    self.height = height 
    self.width = width 
    self.corner_x = corner_x 
    self.corner_y = corner_y
    def centre(self):
      return print("center at(",self.corner_x,",",self.corner_y,")")
      def area(self):
        return self.height * self.width
        def perimeter(self):
          return 2*(self.height + self.width)




h = int(input("Enter height of rectangle: ")) 
w = int(input("Enter width of rectangle: "))
cx= int(input("Enter the corner x of rectangle: ")) 
cy= int(input("Enter the corner y of rectangle: ")) 
obj = Rectangle()
print(obj.Rectangle(h, w, cx, cy, obj))
print("Area of rectangle: ", obj.area())
print("Perimeter of rectangle: ",obj.perimeter())
# Out:
# Enter height of rectangle: 2
# Enter width of rectangle: 3
# Enter the corner x of rectangle: 1
# Enter the corner y of rectangle: 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-0265347b3c43> in <module>()
#      20 cy= int(input("Enter the corner y of rectangle: "))
#      21 obj = Rectangle()
# ---> 22 print(obj.Rectangle(h, w, cx, cy, obj))
#      23 print("Area of rectangle: ", obj.area())
#      24 print("Perimeter of rectangle: ",obj.perimeter())
#
# AttributeError: 'Rectangle' object has no attribute 'Rectangle'

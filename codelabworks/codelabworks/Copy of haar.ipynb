# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
from google.colab import files
from IPython.display import Image

# %%
image = cv2.imread("/content/aiswarya.jpg", 1)
face_detection= cv2.CascadeClassifier('/content/haarcascade_frontalface_default.xml.txt')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
faces = face_detection.detectMultiScale(gray_image, 1.3, 5) # scale factor , min. neighbourhood

for (x,y,w,h) in faces:
   face_image = cv2.rectangle(image,(x,y),(x+w, y+h),(255,0,0),3)
Titles =["haar"] 
images =[face_image] 
count = 1
  
for i in range(count): 
    plt.subplot(2, 2, i + 1) 
    plt.title(Titles[i]) 
    plt.imshow(images[i]) 
  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-14-60e8d45c234c> in <module>()
#       2 face_detection= cv2.CascadeClassifier('/content/haarcascade_frontalface_default.xml.txt')
#       3 gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# ----> 4 faces = face_detection.detectMultiScale(gray_image, 1.3, 5) # scale factor , min. neighbourhood
#       5
#       6 for (x,y,w,h) in faces:
#
# error: OpenCV(4.1.2) /io/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

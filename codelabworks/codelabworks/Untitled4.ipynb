# %%
class Rectangle:
  def init (self,height,width,corner_x,corner_y):


self.height = height self.width = width self.corner_x = corner_x self.corner_y = coy

def centre(self):


return print("center at(",self.corner_x,",",self.corner_y,")")




def area(self):


return self.height * self.width


def perimeter(self):
 
return 2*(self.height + self.width)




h = int(input("Enter height of rectangle: ")) w = int(input("Enter width of rectangle: "))
cx= int(input("Enter the corner x of rectangle: ")) cy= int(input("Enter the corner y of rectangle: ")) obj = Rectangle(h, w, cx, cy)
print(obj.centre())
print("Area of rectangle: ", obj.area()) print("Perimeter of rectangle: ",obj.perimeter())
# Out:
#   File "<ipython-input-1-ad570c2fc8b1>", line 4
#     def init (self,height,width,corner_x,corner_y):
#       ^
# IndentationError: expected an indented block

# %%
list1 = [] 
line = input('Enter the list of tuples:\n') 
while(line != ''): 
	list1.append(tuple(line.split())) 
	line = input()
tup1 =tuple(list1)
print(tup1)
tup2=[]
for x in range(len(tup1)):
    tup2.append(len(tup1[x]))
y=tuple(tup2)
print(y)
# Out:
# Enter the list of tuples:
# 1 2
# 2 4 6
# 4
# 5 0 5
#
# (('1', '2'), ('2', '4', '6'), ('4',), ('5', '0', '5'))
# (2, 3, 1, 3)
